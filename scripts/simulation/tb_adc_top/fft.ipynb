# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nfft


data = pd.read_csv('../../../simulation/simulation/tb_adc_top.sch/ideal.txt', sep=r'\s+', header=None)

x_unit = 1e6
y_unit = 1

# %%
plt.plot(data[0], data[1])

# %%
# Take FFT of signal and take magnitude
fft_result = np.fft.fft(data[1])
fft_mag = np.abs(fft_result) / len(data[3])

# Sample the time with the total time and difference between points
fft_frequency = np.fft.fftfreq(len(data[0]), d=data[0][5]-data[0][4])

plt.loglog(abs(fft_frequency), fft_mag)

# %%
# Take FFT of signal and take magnitude
fft_result = np.fft.fft(data[3])
fft_mag = np.abs(fft_result) / len(data[3])

# Sample the time with the total time and difference between points
fft_frequency = np.fft.fftfreq(len(data[0]), d=data[0][5]-data[0][4])

fig, ax = plt.subplot()
ax.stem(abs(fft_frequency), fft_mag)

ax.set_xscale('log')
ax.set_yscale('log')

plot.shot()
# Out:
# <StemContainer object of 3 artists>

# %%
plt.plot(abs(fft_frequency))
